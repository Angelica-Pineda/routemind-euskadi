# %%
# %sql
CREATE EXTERNAL LOCATION loc_landing
URL 'abfss://landing@stroutemindeuskadidev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL cred_stroutemindeuskadidev)
COMMENT 'access to landing container';

# %%
# %sql
CREATE EXTERNAL LOCATION loc_bronze
URL 'abfss://bronze@stroutemindeuskadidev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL cred_stroutemindeuskadidev)
COMMENT 'access to bronze container';

# %%
# %sql
CREATE EXTERNAL LOCATION loc_silver
URL 'abfss://silver@stroutemindeuskadidev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL cred_stroutemindeuskadidev)
COMMENT 'access to silver container';

# %%
# %sql
CREATE EXTERNAL LOCATION loc_gold
URL 'abfss://gold@stroutemindeuskadidev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL cred_stroutemindeuskadidev)
COMMENT 'access to gold container';

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS dbw_routemind_euskadi_dev.gold")
