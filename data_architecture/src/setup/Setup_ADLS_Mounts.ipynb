# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope="mi_keyvault", key="sp-client-id"),
           "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope="mi_keyvault", key="sp-client-secret"),
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/TU_TENANT_ID/oauth2/token"}

# Landing mount
dbutils.fs.mount(
  source = "abfss://landing@stroutemindeuskadidev.dfs.core.windows.net/",
  mount_point = "/mnt/landing",
  extra_configs = configs)

# Bronze mount
dbutils.fs.mount(
  source = "abfss://bronze@stroutemindeuskadidev.dfs.core.windows.net/",
  mount_point = "/mnt/bronze",
  extra_configs = configs)
